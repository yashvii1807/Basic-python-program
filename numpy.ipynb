# %%
import numpy as np
x = np.array([1, 2, 3])
print(x)
print(type(x))
# Out:
# [1 2 3]
# <class 'numpy.ndarray'>

# %%
y = [1, 2, 3]
print(y)
print(type(y))
# Out:
# [1, 2, 3]
# <class 'list'>

# %%
# %timeit [j**4 for j in range(1,9)]
# Out:
# 819 ns ± 47.8 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
import numpy as np

# %timeit np.arange(1,9)**4
# Out:
# 1.99 μs ± 125 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# Creating Numpy Arrays

# %%
import numpy as np

x = [1, 2, 3, 4, 5]

y = np.array([1, 2, 3, 4, 5])

print(y)
print(type(y))
# Out:
# [1 2 3 4 5]
# <class 'numpy.ndarray'>

# %%
l = []

for i in range(1, 6):
    int_1 = int(input("Enter an integer: "))
    l.append(int_1)

print(np.array(l))
# Out:
# [11 12 13 14 15]
